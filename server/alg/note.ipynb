# %%
import pandas as pd

df = pd.read_csv('schedule.csv')
moorings = pd.read_csv('moorings.csv')

# %%
map_col = df.head().loc[0]
map_col
# Out:
# Уникальный ID записи                                                                                 id
# ID причала                                                                                      dock.id
# Название причала                                                                              dock.name
# Название судна - отсутсвует если отменено                                                     ship.name
# Название маршрута                                                                       route.nameroute
# Швартовочное место                                                                position.berth_letter
# Дата начала действия записи расписания в UTC                                        timetable.startdate
# Дата окончания действиязаписи  расписания в UTC                                       timetable.enddate
# Время подхода судна в минутах от начала суток                                       timetable.starttime
# Время отхода судна в минутах от начала суток                                          timetable.endtime
# Время стоянки                                                                        timetable.duration
# Название судна которое было отменено                                         changed_schedule.ship_name
# Тип записи - пустое знеачение если изменений нет, Отмена - судно отменено         changed_schedule.type
# Дата начала действия записи расписания                                                Начало расписания
# Дата окончания действия записи расписания                                          Окончание расписания
# Причаливание/подход                                                                        Причаливание
# Отход                                                                                             Отход
# Name: 0, dtype: object

# %%
def correct_data(data: pd.DataFrame) -> pd.DataFrame:
    '''
    Приводит датасет в нужный формат
    '''
    return data.rename(dict(zip(data.columns, data.loc[0].values)), axis=1).drop(0)

# %%
df = correct_data(df)
df.head()
# Out:
#         id dock.id       dock.name    ship.name route.nameroute  \
# 1  1093216      45  Воробьевы горы  Алина Браво     Северный 1А
# 2  1094166      32   Нескучный сад        М-250    Исторический
# 3  1094538      32   Нескучный сад    Москва-24        Северный
# 4  1096121      45  Воробьевы горы          NaN     Северный 1А
# 5  1096896      32   Нескучный сад          NaN    Исторический
#
#   position.berth_letter timetable.startdate timetable.enddate  \
# 1                     A          1719954000        1731790800
# 2                     C          1719954000        1731790800
# 3                     B          1719954000        1731790800
# 4                     A          1719954000        1719954000
# 5                     C          1719954000        1719954000
#
#   timetable.starttime timetable.endtime timetable.duration  \
# 1                   1                 5                  4
# 2                   1                 5                  4
# 3                   1                 4                  3
# 4                   1                 5                  4
# 5                   1                 5                  4
#
#   changed_schedule.ship_name changed_schedule.type Начало расписания  \
# 1                        NaN                   NaN          7/3/2024
# 2                        NaN                   NaN          7/3/2024
# 3                        NaN                   NaN          7/3/2024
# 4                Алина Браво                Отмена          7/3/2024
# 5                      М-250                Отмена          7/3/2024
#
#   Окончание расписания Причаливание        Отход
# 1           11/17/2024  12:01:00 AM  12:05:00 AM
# 2           11/17/2024  12:01:00 AM  12:05:00 AM
# 3           11/17/2024  12:01:00 AM  12:04:00 AM
# 4             7/3/2024  12:01:00 AM  12:05:00 AM
# 5             7/3/2024  12:01:00 AM  12:05:00 AM

# %%
moorings = correct_data(moorings)
moorings.head()
# Out:
#   Docs.id      Docs.name                                       Docs.address  \
# 1      31  Парк Горького                              Пушкинская набережная
# 2      32  Нескучный сад  г. Москва, Вверх по течению о.Москва от Крымск...
# 3      33  Крымский мост               Фрунзенская набережная напротив д.10
# 4      39        Марьино                             Батайский проезд, д.33
# 5      41      Печатники                                 ул.Гурьянова, д.35
#
#   Docs.river Docs.latitude Docs.longitude
# 1     Москва     37,597184       55,73013
# 2     Москва     37,590694      55,722427
# 3     Москва     37,596061      55,732427
# 4     Москва     37,725065      55,641785
# 5     Москва     37,714149      55,683699

# %%
df = df.drop('id', axis=1)

# %%
df = df.drop('dock.id', axis=1)
moorings = moorings.drop('Docs.id', axis=1)

# %% [markdown]
# Временно удалим атрибуты timetable.startdate, timetable.enddate

# %%
df = df.drop(['timetable.startdate', 'timetable.enddate'], axis=1)

# %%
df = df.drop(['timetable.starttime', 'timetable.endtime'], axis=1)

# %%
df = df.drop(['Начало расписания', 'Окончание расписания'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7887 entries, 1 to 7887
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   dock.name                   7887 non-null   object
#  1   ship.name                   4129 non-null   object
#  2   route.nameroute             7887 non-null   object
#  3   position.berth_letter       7887 non-null   object
#  4   timetable.duration          7887 non-null   object
#  5   changed_schedule.ship_name  2254 non-null   object
#  6   changed_schedule.type       2254 non-null   object
#  7   Причаливание                7743 non-null   object
#  8   Отход                       7887 non-null   object
# dtypes: object(9)
# memory usage: 554.7+ KB

# %%
col_numeric = ['timetable.duration']

df[col_numeric] = df[col_numeric].astype(int)

# %%
df.describe(include='object')
# Out:
#             dock.name ship.name route.nameroute position.berth_letter  \
# count            7887      4129            7887                  7887
# unique             36        82              11                    14
# top     Нескучный сад  Чижик-II    Исторический                     A
# freq             1157       900            3159                  2803
#
#        changed_schedule.ship_name changed_schedule.type Причаливание  \
# count                        2254                  2254         7743
# unique                         41                     1          956
# top                      Чижик-II                Отмена  12:59:00 AM
# freq                         1188                  2254          114
#
#               Отход
# count          7887
# unique          924
# top     10:00:00 AM
# freq            243

# %%
df['Причаливание'] = pd.to_datetime(df['Причаливание'])
df['Отход'] = pd.to_datetime(df['Отход'])
# Out:
# /tmp/ipykernel_257017/832309581.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Причаливание'] = pd.to_datetime(df['Причаливание'])
# /tmp/ipykernel_257017/832309581.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Отход'] = pd.to_datetime(df['Отход'])

# %%
df.isna().sum()
# Out:
# dock.name                        0
# ship.name                     3758
# route.nameroute                  0
# position.berth_letter            0
# timetable.duration               0
# changed_schedule.ship_name    5633
# changed_schedule.type         5633
# Причаливание                   144
# Отход                            0
# dtype: int64

# %% [markdown]
# пропуски в ship.name = отсутсвуют или отменены (кол-во)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7887 entries, 1 to 7887
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   dock.name                   7887 non-null   object
#  1   ship.name                   4129 non-null   object
#  2   route.nameroute             7887 non-null   object
#  3   position.berth_letter       7887 non-null   object
#  4   timetable.duration          7887 non-null   int64
#  5   changed_schedule.ship_name  2254 non-null   object
#  6   changed_schedule.type       2254 non-null   object
#  7   Причаливание                7743 non-null   datetime64[ns]
#  8   Отход                       7887 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(6)
# memory usage: 554.7+ KB

# %%
import numpy as np

df['changed_schedule.type'] = df['changed_schedule.type'].replace('Отмена', np.nan)
# Out:
# /tmp/ipykernel_257017/3812200950.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['changed_schedule.type'] = df['changed_schedule.type'].replace('Отмена', np.nan)

# %%
df.isna().sum()
# Out:
# dock.name                        0
# ship.name                     3758
# route.nameroute                  0
# position.berth_letter            0
# timetable.duration               0
# changed_schedule.ship_name    5633
# changed_schedule.type         7887
# Причаливание                   144
# Отход                            0
# dtype: int64

# %%
df.shape
# Out:
# (7887, 9)

# %%
df = df.drop('changed_schedule.type', axis=1)

# %%
df = df.dropna(subset='ship.name')

# %%
df = df.drop('changed_schedule.ship_name', axis=1)

# %%
df = df.reset_index(drop='first')

# %% [markdown]
# dock_start фильтр -> ищем dock_end в route.nameroute

# %%
dock_start = 'Воробьевы горы'
dock_end = 'Красный октябрь'
datetime_cur = pd.to_datetime('2024-12-01 15:30:00')

# %% [markdown]
# Название маршрутов, проходящих через данную остановку

# %%
nameroute_arr = df[df['dock.name'] == dock_start]['route.nameroute'].unique()
nameroute_arr
# Out:
# array(['Северный 1А', 'Исторический', 'Северный', 'Разовый подход'],
#       dtype=object)

# %% [markdown]
# Ищем маршруты в которых есть пункт назначения (возможно их нет) и пречаливание которых больше текущего времени

# %%
df[(df['route.nameroute'] == 'Исторический') & (df['dock.name'] == dock_end) & (df['Причаливание'] >= datetime_cur)]
# Out:
#             dock.name             ship.name route.nameroute  \
# 1845  Красный октябрь             Москва-51    Исторический
# 1884  Красный октябрь              Адмиралъ    Исторический
# 1931  Красный октябрь             Москва-61    Исторический
# 2013  Красный октябрь  Полковник Новгородов    Исторический
# 2061  Красный октябрь             Москва-28    Исторический
# ...               ...                   ...             ...
# 3771  Красный октябрь           Алина Танго    Исторический
# 3843  Красный октябрь             Москва-51    Исторический
# 3868  Красный октябрь              Адмиралъ    Исторический
# 3921  Красный октябрь             Москва-61    Исторический
# 3976  Красный октябрь  Полковник Новгородов    Исторический
#
#      position.berth_letter  timetable.duration        Причаливание  \
# 1845                     A                   4 2024-12-01 15:34:00
# 1884                     A                   4 2024-12-01 15:49:00
# 1931                     A                   4 2024-12-01 16:04:00
# 2013                     A                   4 2024-12-01 16:19:00
# 2061                     A                   4 2024-12-01 16:34:00
# ...                    ...                 ...                 ...
# 3771                     A                   4 2024-12-01 22:49:00
# 3843                     A                   4 2024-12-01 23:04:00
# 3868                     A                   4 2024-12-01 23:19:00
# 3921                     A                   4 2024-12-01 23:34:00
# 3976                     A                   4 2024-12-01 23:49:00
#
#                    Отход
# 1845 2024-12-01 15:38:00
# 1884 2024-12-01 15:53:00
# 1931 2024-12-01 16:08:00
# 2013 2024-12-01 16:23:00
# 2061 2024-12-01 16:38:00
# ...                  ...
# 3771 2024-12-01 22:53:00
# 3843 2024-12-01 23:08:00
# 3868 2024-12-01 23:23:00
# 3921 2024-12-01 23:38:00
# 3976 2024-12-01 23:53:00
#
# [145 rows x 7 columns]

# %% [markdown]
# Ищем среди ship.name те, которые еще не отплыли относительно текущего времени

# %%
df[(df['ship.name'] == 'Полковник Новгородов') & (df['dock.name'] == dock_start) & (df['Отход'] >= datetime_cur)]
# Out:
#            dock.name             ship.name route.nameroute  \
# 1840  Воробьевы горы  Полковник Новгородов    Исторический
# 2031  Воробьевы горы  Полковник Новгородов  Разовый подход
# 2357  Воробьевы горы  Полковник Новгородов  Разовый подход
# 2456  Воробьевы горы  Полковник Новгородов    Исторический
# 2658  Воробьевы горы  Полковник Новгородов  Разовый подход
# 3057  Воробьевы горы  Полковник Новгородов  Разовый подход
# 3153  Воробьевы горы  Полковник Новгородов    Исторический
# 3357  Воробьевы горы  Полковник Новгородов  Разовый подход
# 3841  Воробьевы горы  Полковник Новгородов    Исторический
#
#      position.berth_letter  timetable.duration        Причаливание  \
# 1840                     B                  10 2024-12-01 15:32:00
# 2031                     B                   5 2024-12-01 16:25:00
# 2357                     B                   5 2024-12-01 17:40:00
# 2456                     B                  10 2024-12-01 18:02:00
# 2658                     B                   5 2024-12-01 18:55:00
# 3057                     B                   5 2024-12-01 20:10:00
# 3153                     B                  10 2024-12-01 20:32:00
# 3357                     B                   5 2024-12-01 21:25:00
# 3841                     B                  10 2024-12-01 23:02:00
#
#                    Отход
# 1840 2024-12-01 15:42:00
# 2031 2024-12-01 16:30:00
# 2357 2024-12-01 17:45:00
# 2456 2024-12-01 18:12:00
# 2658 2024-12-01 19:00:00
# 3057 2024-12-01 20:15:00
# 3153 2024-12-01 20:42:00
# 3357 2024-12-01 21:30:00
# 3841 2024-12-01 23:12:00

# %%
data = pd.DataFrame(columns=df.columns)
for nameroute in nameroute_arr:
    # пункт B
    ship_list = df[(df['route.nameroute'] == nameroute) & (df['dock.name'] == dock_end) & (df['Причаливание'] > datetime_cur)]['ship.name'].unique()
    for ship_name in ship_list:
        # пункт A
        data = pd.concat([data, df[(df['ship.name'] == ship_name) & (df['dock.name'] == dock_start) & (df['Отход'] >= datetime_cur)]])
data.sort_values('Отход')
# Out:
# /tmp/ipykernel_257017/3605069621.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data = pd.concat([data, df[(df['ship.name'] == ship_name) & (df['dock.name'] == dock_start) & (df['Отход'] >= datetime_cur)]])
#            dock.name             ship.name route.nameroute  \
# 1855  Воробьевы горы                ОМ-349  Разовый подход
# 1840  Воробьевы горы  Полковник Новгородов    Исторический
# 1865  Воробьевы горы                 М-250  Разовый подход
# 1882  Воробьевы горы             Москва-28    Исторический
# 1927  Воробьевы горы                 М-250    Исторический
# ...              ...                   ...             ...
# 3966  Воробьевы горы              Чижик-II    Исторический
# 3967  Воробьевы горы              Чижик-II    Исторический
# 3938  Воробьевы горы             Олимпиада    Исторический
# 3935  Воробьевы горы              Чижик-II    Исторический
# 3973  Воробьевы горы              Чижик-II    Исторический
#
#      position.berth_letter timetable.duration        Причаливание  \
# 1855                     B                  5 2024-12-01 15:35:00
# 1840                     B                 10 2024-12-01 15:32:00
# 1865                     B                  5 2024-12-01 15:40:00
# 1882                     B                 10 2024-12-01 15:47:00
# 1927                     B                 10 2024-12-01 16:02:00
# ...                    ...                ...                 ...
# 3966                     B                 10 2024-12-01 23:47:00
# 3967                     B                 10 2024-12-01 23:47:00
# 3938                     B                 10 2024-12-01 23:47:00
# 3935                     B                 10 2024-12-01 23:47:00
# 3973                     B                 10 2024-12-01 23:47:00
#
#                    Отход
# 1855 2024-12-01 15:40:00
# 1840 2024-12-01 15:42:00
# 1865 2024-12-01 15:45:00
# 1882 2024-12-01 15:57:00
# 1927 2024-12-01 16:12:00
# ...                  ...
# 3966 2024-12-01 23:57:00
# 3967 2024-12-01 23:57:00
# 3938 2024-12-01 23:57:00
# 3935 2024-12-01 23:57:00
# 3973 2024-12-01 23:57:00
#
# [200 rows x 7 columns]

# %% [markdown]
# Примем, что все корабли с одинаковым названием движутся по одному и тому же маршруту одинаковое кол-во времени

# %%
moorings.dtypes
# Out:
# Docs.name         object
# Docs.address      object
# Docs.river        object
# Docs.latitude     object
# Docs.longitude    object
# dtype: object

# %%
moorings['Docs.latitude'] = moorings['Docs.latitude'].apply(lambda x: float(x.replace(',', '.')))
moorings['Docs.longitude'] = moorings['Docs.longitude'].apply(lambda x: float(x.replace(',', '.')))

# %%
def distance(p1: float, p2: float, q1: float, q2: float) -> float:
    '''
    Вычисляет манхетанское расстояние (в км)
    '''
    k = 0.95 / 0.01419299999999879 # перевод в км (ПГ - Нескучный шаг)
    return (abs(p1 - q1) + abs(p2 - q2)) * k

def cord_to_dock(latitude: float, longitude: float) -> list:
    '''
    Возвращает список причалов, отсортированных по близости к текущей точке
    '''
    dock_names = moorings['Docs.name']
    res_list = []
    
    for dock_name in dock_names:
        dock_data = moorings[moorings['Docs.name'] == dock_name]
        dock_latitide = dock_data['Docs.latitude'].values[0] 
        dock_longitude = dock_data['Docs.longitude'].values[0]
        
        res_list.append((dock_name, distance(latitude, longitude, dock_latitide, dock_longitude)))
    
    return sorted(res_list, key=lambda x: x[1])

def dock_shedule(dock_start, dock_end, datetime_cur):
    '''
    Релевантное расписание для причала
    '''
    data = pd.DataFrame(columns=df.columns)
    nameroute_arr = df[df['dock.name'] == dock_start]['route.nameroute'].unique()
    
    for nameroute in nameroute_arr:
        # пункт B
        ship_list = df[(df['route.nameroute'] == nameroute) & (df['dock.name'] == dock_end) & (df['Причаливание'] > datetime_cur)]['ship.name'].unique()
        for ship_name in ship_list:
            # пункт A
            data = pd.concat([data, df[(df['ship.name'] == ship_name) & (df['dock.name'] == dock_start) & (df['Отход'] >= datetime_cur)]])
    
    return data.sort_values('Отход')
    

def shedule(latitude: float, longitude: float, dock_end: str, datetime_cur: str) -> pd.DataFrame:
    '''
    Создание релевантного расписания.
    
    Аргументы функции:  
    latitude - долгота точки клиента
    longitude - широта точки клиента
    dock_end - пункт назначения, название причала
    datetime_cur - текущая дата и время, в формате 'YYYY-MM-DD HH:MM:SS' (24-часовом формате времени)
    '''
    nearest_docks = cord_to_dock(latitude, longitude)[:3]
    datetime_cur = pd.to_datetime(datetime_cur)
    
    res_df = pd.DataFrame(columns=df.columns)
    for dock in nearest_docks:
        res_df = pd.concat([res_df, dock_shedule(dock[0], dock_end, datetime_cur)])
        
    return res_df.sort_values('Отход')

# %%
cord_to_dock(37.597184, 55.73013)
# Out:
# [('Парк Горького', np.float64(0.0)),
#  ('Крымский мост', np.float64(0.22891566265051647)),
#  ('Нескучный сад', np.float64(0.95)),
#  ('Патриарший', np.float64(1.6597054886209537)),
#  ('Красный октябрь', np.float64(1.9037483266399415)),
#  ('Третьяковский', np.float64(2.3829986613119334)),
#  ('Киевский', np.float64(2.602878179384121)),
#  ('Андреевский', np.float64(2.906961178045813)),
#  ('Зарядье', np.float64(3.4441767068272426)),
#  ('Лужники – Северный', np.float64(3.699866131192171)),
#  ('Новоспасский', np.float64(3.7723560910306686)),
#  ('Автозаводский мост', np.float64(3.7979919678722753)),
#  ('Китай-город', np.float64(3.8175368139227874)),
#  ('Трёхгорный', np.float64(3.839892904953256)),
#  ('ЗИЛ', np.float64(4.142322623829317)),
#  ('Лужники - Центральный', np.float64(4.329585006693792)),
#  ('Сити – Багратион', np.float64(4.571753681392334)),
#  ('Воробьевы горы', np.float64(4.601740294511866)),
#  ('Сити – Экспоцентр', np.float64(4.6186746987952425)),
#  ('Сити – Центральный', np.float64(4.815930388219551)),
#  ('Кутузовский', np.float64(4.9032128514059465)),
#  ('Береговой', np.float64(7.552342704150401)),
#  ('Сердце Столицы', np.float64(7.717892904953153)),
#  ('Кленовый бульвар', np.float64(7.941030789827238)),
#  ('Южный речной вокзал', np.float64(7.990428380188578)),
#  ('Меловой', np.float64(9.28400267737741)),
#  ('Парк Фили', np.float64(9.43500669344091)),
#  ('Нагатинский затон', np.float64(9.92048192771175)),
#  ('Печатники', np.float64(10.936813922357416)),
#  ('Серебряный бор-3', np.float64(13.875435073628962)),
#  ('Марьино', np.float64(14.47295850067098)),
#  ('Серебряный бор-2', np.float64(15.286546184740182)),
#  ('Троице-Лыково', np.float64(16.712516733601987)),
#  ('Северный речной вокзал', np.float64(16.87021419009504)),
#  ('Захарково', np.float64(17.204953145918363)),
#  ('Химки', np.float64(19.725903614459067))]

# %%
test_shedule = shedule(37.597184, 55.73013, 'Воробьевы горы', '2024-12-01 15:30:00')
test_shedule
# Out:
# /tmp/ipykernel_257017/2318264412.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data = pd.concat([data, df[(df['ship.name'] == ship_name) & (df['dock.name'] == dock_start) & (df['Отход'] >= datetime_cur)]])
# /tmp/ipykernel_257017/2318264412.py:56: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df = pd.concat([res_df, dock_shedule(dock[0], dock_end, datetime_cur)])
#           dock.name       ship.name route.nameroute position.berth_letter  \
# 1836  Нескучный сад       Снегири-4        Северный                     B
# 1834  Нескучный сад        Адмиралъ    Исторический                     C
# 1844  Нескучный сад           Прага        Северный                     A
# 1857  Нескучный сад       Москва-21     Северный 1А                     B
# 1870  Нескучный сад  Михаил Сеспель     Северный 1А                     A
# ...             ...             ...             ...                   ...
# 3927  Нескучный сад           Удача     Северный 1А                     B
# 3932  Нескучный сад       Снегири-4        Северный                     B
# 3934  Нескучный сад       Москва-28    Исторический                     C
# 3975  Нескучный сад           Прага        Северный                     A
# 3980  Нескучный сад       Москва-21     Северный 1А                     B
#
#      timetable.duration        Причаливание               Отход
# 1836                  3 2024-12-01 15:31:00 2024-12-01 15:34:00
# 1834                  4 2024-12-01 15:31:00 2024-12-01 15:35:00
# 1844                  4 2024-12-01 15:34:00 2024-12-01 15:38:00
# 1857                  3 2024-12-01 15:38:00 2024-12-01 15:41:00
# 1870                  4 2024-12-01 15:41:00 2024-12-01 15:45:00
# ...                 ...                 ...                 ...
# 3927                  3 2024-12-01 23:38:00 2024-12-01 23:41:00
# 3932                  3 2024-12-01 23:46:00 2024-12-01 23:49:00
# 3934                  4 2024-12-01 23:46:00 2024-12-01 23:50:00
# 3975                  4 2024-12-01 23:49:00 2024-12-01 23:53:00
# 3980                  3 2024-12-01 23:53:00 2024-12-01 23:56:00
#
# [320 rows x 7 columns]
